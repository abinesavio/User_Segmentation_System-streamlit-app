# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1aa3dc4fa683> in <module>
# ----> 1 import streamlit as st
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
# !pip install streamlit

# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-1aa3dc4fa683> in <module>
# ----> 1 import streamlit as st
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.29.0-py2.py3-none-any.whl (8.4 MB)
# ...
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# ...
#   Using cached watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
# ...
#   Using cached GitPython-3.1.40-py3-none-any.whl (190 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached rich-13.7.0-py3-none-any.whl (240 kB)
# ...
#   Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# ...
#   Using cached pyarrow-14.0.2-cp38-cp38-win_amd64.whl (24.6 MB)
# ...
#   Using cached altair-5.2.0-py3-none-any.whl (996 kB)
# ...
#   Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# ...
#   Using cached validators-0.22.0-py3-none-any.whl (26 kB)
# ...
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# ...
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# ...
#   Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl (99 kB)
# ...
#   Using cached pygments-2.17.2-py3-none-any.whl (1.2 MB)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# -atplotlib                         3.3.4
# absl-py                            1.4.0
# alabaster                          0.7.12
# altair                             5.2.0
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              3.7.1
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# Automat                            22.10.0
# autopep8                           1.5.6
# ...

# %%
import streamlit as st

# %%
import pandas as pd

# Function to read and display CSV file
def read_and_display_csv(file):
    df = pd.read_csv(file)
    st.write(df)

# Main Streamlit app
def main():
    st.title("CSV File Upload and Display")

    # File upload section
    uploaded_file = st.file_uploader("Upload a CSV file", type=["csv"])

    if uploaded_file is not None:
        # Display the uploaded file
        st.subheader("Uploaded CSV file:")
        read_and_display_csv(uploaded_file)

    # Prediction button (you can replace this with your prediction logic)
    if st.button("Predict"):
        st.write("Prediction button clicked!")

if __name__ == "__main__":
    main()
# Out:
# 2024-01-04 12:43:15.266
# ...
#   command:
#
#     streamlit run C:\Users\abine\Contacts\PYTHON\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
streamlit run app.py
# Out:
#   File "<ipython-input-8-718866ff34b9>", line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax
